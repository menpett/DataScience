# %% [markdown]
# *Creado por:*
#
# *Isabel Maniega*

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Preprocesado y análisis
#
# !pip install scipy
# !pip install statsmodels

# %%
# Preprocesado y análisis
import statsmodels.api as sm
from scipy import stats

# %% [markdown]
# # Ejercicio
#
# Dada estos valores:
#     15 16 17
#     16 21 22
#     15 16 15
#     17 16 22
#     14 13 14
#     14 15 15
#     14 15 16
#     10 19 15
#     15 22 24
#     25 15 16

# %%
lista = '15 16 17 16 21 22 15 16 15 17 16 22 14 13 14 14 15 15 14 15 16 10 19 15 15 22 24 25 15 16'
lista = lista.split(' ')
valores = []
for i in lista:
    valores.append(int(i))

# %%
df = pd.DataFrame({"Valores": valores})
df.head()
# Out:
#    Valores
# 0       15
# 1       16
# 2       17
# 3       16
# 4       21

# %%
df = pd.DataFrame(valores, columns = ["Valores"])
df.head()
# Out:
#    Valores
# 0       15
# 1       16
# 2       17
# 3       16
# 4       21

# %% [markdown]
# ### Utilizando PANDAS

# %% [markdown]
# **1)** Realiza un Histograma con tamaño de barra 2.

# %%
df.Valores.plot(kind = 'hist',xlabel = 'Y values', ylabel = 'Frequency', color = 'green', rwidth = 0.25, bins = 2)
plt.show()

# %% [markdown]
# **2)** ¿Cuál es el número que más se repite?

# %%
moda = df.Valores.mode()
moda.loc[0]
# Out:
# 15

# %%
df.Valores.value_counts()
# Out:
# 15    9
# 16    6
# 14    4
# 22    3
# 17    2
# 21    1
# 13    1
# 10    1
# 19    1
# 24    1
# 25    1
# Name: Valores, dtype: int64

# %% [markdown]
# **3)** ¿Qué pasa si cambiamos a tamaño de barra 5?

# %%
df.Valores.plot(kind = 'hist',xlabel = 'Y values', ylabel = 'Frequency', color = 'green', rwidth = 0.25, bins = 5)
plt.show()

# %% [markdown]
# **4)** ¿Qué pasa si cambiamos a tamaño de barra 20?

# %%
df.Valores.plot(kind = 'hist',xlabel = 'Y values', ylabel = 'Frequency', color = 'green', rwidth = 0.25, bins = 20)
plt.show()

# %% [markdown]
# **5)** ¿Qué parece indicar el sesgo en la distribución?

# %%
# valores de la media (mu) y desviación típica (sigma) de los datos
mu, sigma = stats.norm.fit(df.Valores)
x_hat = np.linspace(min(df.Valores), max(df.Valores), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)
# Gráfico
fig, ax = plt.subplots(figsize=(7, 4))
ax.plot(x_hat, y_hat, linewidth=2, label="normal")
# ax.hist(x=notas_1, density=True, bins=30, color="#3182bd", alpha=0.5)
ax.plot(df.Valores, np.full_like(df.Valores, -0.01), "|k", markeredgewidth=1)
ax.set_title("Distribución df.Valores")
ax.set_xlabel("Valores")
ax.set_ylabel("Densidad de probabilidad")
ax.legend()
plt.show()

# %%
mu, sigma = stats.norm.fit(df.Valores)
x_hat = np.linspace(min(df.Valores), max(df.Valores), num=100)
y_hat = stats.norm.pdf(x_hat, mu, sigma)
df1 = pd.DataFrame({'x_hat': x_hat, 'y_hat': y_hat})
df1.plot()
plt.show()

# %% [markdown]
# *Creado por*
#
# *Isabel Maniega*
